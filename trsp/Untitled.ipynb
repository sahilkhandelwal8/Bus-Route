# %%
from flask import Flask, render_template,request
import folium
app = Flask(__name__)

@app.route('/')
def landing_page():
    return render_template('landing_page.html')

@app.route('/best_route')
def best_route():
    # No need to create a Folium map, just render the existing HTML file
    return render_template('best_route.html')

@app.route('/custom_route', methods=['GET', 'POST'])
def custom_route():
    if request.method == 'POST':
        # Get user-selected values from the form
        stop1 = request.form.get('stop1')
        stop2 = request.form.get('stop2')
        no_of_stops = int(request.form.get('no_of_stops'))

        # Generate a Folium map based on user-selected values
        my_map = generate_custom_route_map(stop1, stop2, no_of_stops)

        # Save the map as an HTML file
        my_map.save("templates/custom_route_map.html")

        # Render the template with the map
        return render_template('custom_route.html',max_stops=5)

    # Render the form initially
    return render_template('custom_route.html', stops=['Place1', 'Place2', 'Place3'],max_stops=5)

def generate_custom_route_map(stop1, stop2, no_of_stops):
    # Add logic to generate a Folium map based on user-selected values
    # You can customize this based on your use case
    my_map = folium.Map(location=[51.5074, -0.1278], zoom_start=12)  # London coordinates as an example

    # Add markers, routes, etc. based on the user-selected values

    return my_map

if __name__ == '__main__':
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [04/Feb/2024 18:47:41] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Feb/2024 18:47:42] "GET /custom_route HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Feb/2024 18:47:43] "POST /custom_route HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Feb/2024 19:25:12] "GET /custom_route HTTP/1.1" 200 -
# [2024-02-04 19:25:15,707] ERROR in app: Exception on /best_route [GET]
# Traceback (most recent call last):
#   File "D:\Anaconda\lib\site-packages\flask\app.py", line 1455, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\Anaconda\lib\site-packages\flask\app.py", line 869, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\Anaconda\lib\site-packages\flask\app.py", line 867, in full_dispatch_request
# ...
